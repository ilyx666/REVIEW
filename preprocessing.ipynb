# %%
import pandas as pd
df = pd.read_excel('rewiew.xlsx')

# %%
df
# Out:
#      Unnamed: 0             rewiew_ID    article                  Date  \
# 0             0  _yhkHIcBQOOSTxXoG9Dz  135608212  26-03-2023 05:28:56
# 1             1  ewAXGIcB5HDhYKpHJk0M  135608212  25-03-2023 09:26:23
# 2             2  bH6qCYcBv9_TjX_mhNNe  135608212  22-03-2023 14:13:03
# 3             3  5Hz4A4cBk9xzjhYZmnGz  135608212  21-03-2023 11:40:37
# 4             4  3BZWAIcBxpMXtsmOsFFg  135608212  20-03-2023 18:44:54
# ..          ...                   ...        ...                   ...
# 694         694  3pZCp4UBQBfka8TNcNCu  104288888  12-01-2023 18:33:47
# 695         695  WWBQVIUBxpMXtsmOF6MD  104288888  27-12-2022 16:00:13
# 696         696  1bsAPoUBv9_TjX_mkPr5  104288888  23-12-2022 08:01:42
# 697         697  Y0W194QBMBFuPskoAlHI  104288888  09-12-2022 16:25:45
# 698         698  Rl81zYQBI2nds0aGxveK  104288888  01-12-2022 10:22:44
#
#               Name  Rating                                             Rewiew  \
# ...

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install --upgrade emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from pymystem3 import Mystem

# загружаем стоп-слова для русского языка
nltk.download('stopwords')
stop_words = set(stopwords.words('russian'))

# создаем объект лемматизатора
m = Mystem()

# функция для предобработки текста
def preprocess_text(text):
    # удаляем ссылки и хэштеги
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'#\S+', '', text)
    # удаляем знаки препинания
    text = text.translate(str.maketrans('', '', string.punctuation))
    # приводим к нижнему регистру
    text = text.lower()
    # лемматизируем текст
    lemmas = m.lemmatize(text)
    # удаляем стоп-слова
    filtered_lemmas = [lemma for lemma in lemmas if lemma.strip() and lemma not in stop_words]
    # объединяем леммы в строку
    filtered_text = ' '.join(filtered_lemmas)
    return filtered_text

# применяем функцию к каждому элементу столбца Rewiew
for idx in range(len(df['Rewiew'])):
    df['Rewiew'][idx] = preprocess_text(df['Rewiew'][idx])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-17-f0c356a9495e>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rewiew'][idx] = preprocess_text(df['Rewiew'][idx])

# %%
import unicodedata
import emoji
new_line_list = []
for line_list in df.Rewiew:
  for word in line_list:
    emojis = emoji.distinct_emoji_list(word)
    new_line_list.extend([emoji.demojize(is_emoji) for is_emoji in emojis])
print(new_line_list)
# Out:
# [':backhand_index_pointing_up:', ':thumbs_up:', ':thumbs_up:', ':thumbs_up:', ':light_skin_tone:', ':thumbs_up:', ':light_skin_tone:', ':thumbs_up:', ':light_skin_tone:', ':thumbs_up:', ':thumbs_up:', ':thumbs_up:', ':face_holding_back_tears:', ':thumbs_up:', ':thumbs_up:', ':thumbs_up:', ':thumbs_up:', ':thumbs_up:', ':folded_hands:', ':light_skin_tone:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':cherry_blossom:', ':beaming_face_with_smiling_eyes:', ':beaming_face_with_smiling_eyes:', ':beaming_face_with_smiling_eyes:', ':thinking_face:', ':fire:', ':winking_face:', ':thumbs_up:', ':smiling_face_with_heart-eyes:', ':fire:', ':thumbs_up:', ':thumbs_up:', ':slightly_smiling_face:', ':thumbs_up:', ':crossed_fingers:', ':face_blowing_a_kiss:', ':thumbs_up:', ':slightly_smiling_face:', ':folded_hands:', ':light_skin_tone:', ':slig
# ...

# %%
for idx in range(len(df.Rewiew)):
    # преобразовать значение ячейки смайлика
    converted_review = emoji.demojize(df.Rewiew.iloc[idx])
    # присвоить значение ячейки в DataFrame
    df.Rewiew.iloc[idx] = converted_review
# Out:
# <ipython-input-19-43a706a1f0f8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Rewiew.iloc[idx] = converted_review

# %%
df.Rewiew = df.Rewiew.str.lower()

# %%
for i in df.Rewiew:
  print(i)
# Out:
# ноутбук довольный приходить аккуратно добротно упакованочень эстетичный внешний вид действительно приятно рука держать работа вообще огонь учеба работа игровой приложение подходить вполне уровень яркость экран умеренный изображение четкий глаз раздражать вполне работать очки компьютер клавиатура средний жесткость очень удобный вишенка торт подсветка клавиатура р нравиться покупать подарок сын сын довольный ноутбук покупка рекомендовать
# ноутбук хороший сначала заряжаться оказываться провод нужно вставлять разъем милый надовивать щелчок открываться меню shell прописывать exit установка гайд посмотреть
# отличный ноутбук работать 11 винд легко вставать
# отлично работать взять 48 отличный цена рекомендовать :backhand_index_pointing_up:
# отлично :thumbs_up: приходить целый работать доставлять быстро
# понравиться весь отлично спасибо быстрый доставка время показывать пока весь :thumbs_up:
# приходить неисправный включаться заряжать очень расстраивать дизлайк
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('russian'))

for idx in range(len(df.Rewiew)):
  text = df.Rewiew.iloc[idx]
  text_tokens = text.split()
  filtered_tokens = [word for word in text_tokens if word.lower() not in stop_words]
  filtered_text = ' '.join(filtered_tokens)
  df.Rewiew.iloc[idx] = filtered_text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-22-35e662a482fd>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Rewiew.iloc[idx] = filtered_text

# %%
for i in df.Rewiew:
  print(i)
# Out:
# ноутбук довольный приходить аккуратно добротно упакованочень эстетичный внешний вид действительно приятно рука держать работа вообще огонь учеба работа игровой приложение подходить вполне уровень яркость экран умеренный изображение четкий глаз раздражать вполне работать очки компьютер клавиатура средний жесткость очень удобный вишенка торт подсветка клавиатура р нравиться покупать подарок сын сын довольный ноутбук покупка рекомендовать
# ноутбук хороший сначала заряжаться оказываться провод нужно вставлять разъем милый надовивать щелчок открываться меню shell прописывать exit установка гайд посмотреть
# отличный ноутбук работать 11 винд легко вставать
# отлично работать взять 48 отличный цена рекомендовать :backhand_index_pointing_up:
# отлично :thumbs_up: приходить целый работать доставлять быстро
# понравиться весь отлично спасибо быстрый доставка время показывать пока весь :thumbs_up:
# приходить неисправный включаться заряжать очень расстраивать дизлайк
# ...

# %%
df
# Out:
#      Unnamed: 0             rewiew_ID    article                  Date  \
# 0             0  _yhkHIcBQOOSTxXoG9Dz  135608212  26-03-2023 05:28:56
# 1             1  ewAXGIcB5HDhYKpHJk0M  135608212  25-03-2023 09:26:23
# 2             2  bH6qCYcBv9_TjX_mhNNe  135608212  22-03-2023 14:13:03
# 3             3  5Hz4A4cBk9xzjhYZmnGz  135608212  21-03-2023 11:40:37
# 4             4  3BZWAIcBxpMXtsmOsFFg  135608212  20-03-2023 18:44:54
# ..          ...                   ...        ...                   ...
# 694         694  3pZCp4UBQBfka8TNcNCu  104288888  12-01-2023 18:33:47
# 695         695  WWBQVIUBxpMXtsmOF6MD  104288888  27-12-2022 16:00:13
# 696         696  1bsAPoUBv9_TjX_mkPr5  104288888  23-12-2022 08:01:42
# 697         697  Y0W194QBMBFuPskoAlHI  104288888  09-12-2022 16:25:45
# 698         698  Rl81zYQBI2nds0aGxveK  104288888  01-12-2022 10:22:44
#
#               Name  Rating                                             Rewiew  \
# ...

# %%
df.to_excel('review_preprocessing.xlsx')
