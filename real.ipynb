# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('review_preprocessing.xlsx')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1             rewiew_ID    article  \
# 0              0             0  y1a2e4cBpT2rITcGXb5U  123837570
# 1              1             1  uLDLeocB5g4sVs4D8-56  123837570
# 2              2             2  rWodeocBYE-HFOZ5m9-H  123837570
# 3              3             3  H2r7eYcBYE-HFOZ529Vf  123837570
# 4              4             4  PALIdocBl47NwnZ1Tx-R  123837570
# ...          ...           ...                   ...        ...
# 8952        8952          8952  3pZCp4UBQBfka8TNcNCu  104288888
# 8953        8953          8953  WWBQVIUBxpMXtsmOF6MD  104288888
# 8954        8954          8954  1bsAPoUBv9_TjX_mkPr5  104288888
# 8955        8955          8955  Y0W194QBMBFuPskoAlHI  104288888
# 8956        8956          8956  Rl81zYQBI2nds0aGxveK  104288888
#
#                       Date           Name  Rating  \
# 0     13-04-2023 17:42:42        Владимир       3
# 1     13-04-2023 13:26:39         Алексей       5
# ...

# %%
lens = []
for i in df.Rewiew:
    lens.append(len(str(i)))

# %%
df['LenReview'] = lens
print(df['LenReview'].mean())
print(df['LenReview'].median())
# Out:
# 75.66841576420677
# 47.0

# %%
plt.plot(lens)
plt.show()
lens

# %%
import random

# %%
for i in range(len(df)):
    if df['LenReview'].loc[i] < 47 and df['Rating'].loc[i] < 3:
        df['isReal'].loc[i] = 0
    else:
        df['isReal'].loc[i] = 1
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
from collections import Counter
print(Counter(df.isReal))
# Out:
# Counter({1: 8791, 0: 166})

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1             rewiew_ID    article  \
# 0              0             0  y1a2e4cBpT2rITcGXb5U  123837570
# 1              1             1  uLDLeocB5g4sVs4D8-56  123837570
# 2              2             2  rWodeocBYE-HFOZ5m9-H  123837570
# 3              3             3  H2r7eYcBYE-HFOZ529Vf  123837570
# 4              4             4  PALIdocBl47NwnZ1Tx-R  123837570
# ...          ...           ...                   ...        ...
# 8952        8952          8952  3pZCp4UBQBfka8TNcNCu  104288888
# 8953        8953          8953  WWBQVIUBxpMXtsmOF6MD  104288888
# 8954        8954          8954  1bsAPoUBv9_TjX_mkPr5  104288888
# 8955        8955          8955  Y0W194QBMBFuPskoAlHI  104288888
# 8956        8956          8956  Rl81zYQBI2nds0aGxveK  104288888
#
#                       Date           Name  Rating  \
# 0     13-04-2023 17:42:42        Владимир       3
# 1     13-04-2023 13:26:39         Алексей       5
# ...

# %%
import numpy as np
for i in range(len(df)):
    if type(df.Rewiew.loc[i]) == float:
        df.Rewiew.loc[i] = ''
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1             rewiew_ID    article  \
# 0              0             0  y1a2e4cBpT2rITcGXb5U  123837570
# 1              1             1  uLDLeocB5g4sVs4D8-56  123837570
# 2              2             2  rWodeocBYE-HFOZ5m9-H  123837570
# 3              3             3  H2r7eYcBYE-HFOZ529Vf  123837570
# 4              4             4  PALIdocBl47NwnZ1Tx-R  123837570
# ...          ...           ...                   ...        ...
# 8952        8952          8952  3pZCp4UBQBfka8TNcNCu  104288888
# 8953        8953          8953  WWBQVIUBxpMXtsmOF6MD  104288888
# 8954        8954          8954  1bsAPoUBv9_TjX_mkPr5  104288888
# 8955        8955          8955  Y0W194QBMBFuPskoAlHI  104288888
# 8956        8956          8956  Rl81zYQBI2nds0aGxveK  104288888
#
#                       Date           Name  Rating  \
# 0     13-04-2023 17:42:42        Владимир       3
# 1     13-04-2023 13:26:39         Алексей       5
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df.Rewiew)

# %%
y =
